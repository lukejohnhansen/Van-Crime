# %% [markdown]
# #Vancouver Crime Analysis Program
# #####Author: Luke Hansen
# ---
# <b>What - </b>This notebook will report the top crimes in popular neighbourhoods in Vancouver, predict the number of certain crimes, and attempt to find a corelation between crime rates and housing values.
#
# ---
# <b>Why - </b>The goal of this project is to teach myself:
# - basic big data principles
# - Python 3
# - Apache Spark
# - Apache Kafka
# - the databricks platform
#
# ---
#
# <b>How - </b>Datasets Used:
#
# The Vancouver Police Department's CSV dataset (2003 - present): https://data.vancouver.ca/datacatalogue/crime-data.htm
#
# Vancouver property tax datasets (2006 - 2018): https://data.vancouver.ca/datacatalogue/propertyTax.htm
#
# ---
#
# <b>Conclusions - </b> Final speculations:
#
# The higher the property market, the higher the crime there will be.
#
# The lower the property market, the lower the crime will be.
#
# #####The main speculation that I've made is that the crime rate goes up and down with the market due to affordability for housing, as people can be pushed to crime if they cannot afford housing.
#
# ---
#
# ####Content:
# 1. Crime in Vancouver
# 2. Housing Values in Vancouver
# 3. Corelations Between Crime Rates and Housing Values

# %% [markdown]
# ##1. Crime in Vancouver

# %% [markdown]
# The first task to be completed is to import the crime data from the DBFS into the notebook (NOTE: I plan to use Apache Kafka to fetch the data real-time on each execution of this notebook, but for now I'll just manually download the datasets individually and upload them to Databricks).

# %%
#todo connect apache kafka to fetch data in real time

# import crime csv file from DBFS
crime_path = "/FileStore/tables/crime_csv_all_years.csv"
crime_dataset = spark.read.csv(crime_path, inferSchema=True, header=True)

crime_dataset.show(20)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+----+-----+---+----+------+--------------------+--------------------+---------+----------+
#                 TYPE|YEAR|MONTH|DAY|HOUR|MINUTE|       HUNDRED_BLOCK|       NEIGHBOURHOOD|        X|         Y|
# +--------------------+----+-----+---+----+------+--------------------+--------------------+---------+----------+
#   Theft from Vehicle|2003|    5| 14|   0|     0|   11XX CONNAUGHT DR|         Shaughnessy|490368.39|5454609.25|
# Break and Enter R...|2003|    5| 19|  22|    30|       18XX COMOX ST|            West End|489813.77|5459590.38|
#   Theft from Vehicle|2003|    1| 17|  21|    30|       21XX YORK AVE|           Kitsilano|488818.32| 5457672.4|
#   Theft from Vehicle|2003|    1| 17|  18|    30|       21XX YORK AVE|           Kitsilano|488818.32| 5457672.4|
#   Theft from Vehicle|2003|    5| 17|  17|     0|      6XX BURRARD ST|Central Business ...|491279.21|5459177.42|
# Break and Enter R...|2003|    1| 18|   9|     0|      33XX E 2ND AVE|    Hastings-Sunrise|497666.36|5457305.02|
# Offence Against a...|2003|   11|  1|null|  null|OFFSET TO PROTECT...|                null|      0.0|       0.0|
# Break and Enter R...|2003|    7|  7|  11|     0|        66XX MAIN ST|              Sunset|492601.32|5452351.02|
#   Theft from Vehicle|2003|    1| 10|   1|     0|       21XX YORK AVE|           Kitsilano|488818.32| 5457672.4|
#   Theft from Vehicle|2003|   11|  3|  17|    55|BURRARD ST / COMO...|            West End|490757.46|5458643.86|
# Offence Against a...|2003|    4| 27|null|  null|OFFSET TO PROTECT...|                null|      0.0|       0.0|
#   Theft from Vehicle|2003|    3| 11|  21|     0|   21XX WAVERLEY AVE| Victoria-Fraserview|495350.96|5452706.74|
# Break and Enter R...|2003|   11| 17|  19|    20|      33XX E 2ND AVE|    Hastings-Sunrise|497708.07|5457295.56|
# Offence Against a...|2003|   11|  4|null|  null|OFFSET TO PROTECT...|                null|      0.0|       0.0|
# Break and Enter R...|2003|   10| 17|  15|    30|      18XX COTTON DR|  Grandview-Woodland|494787.03|5457299.84|
# Break and Enter R...|2003|    6|  4|  15|    30|      18XX COTTON DR|  Grandview-Woodland|494796.22|5457303.43|
#   Theft from Vehicle|2003|    7| 11|  19|     0|  21XX WATERSIDE AVE| Victoria-Fraserview|495310.45|5450562.68|
# Break and Enter R...|2003|    2| 20|  11|    30|      33XX E 3RD AVE|    Hastings-Sunrise|497571.63|5457204.76|
# Break and Enter C...|2003|    9| 26|   2|    30|     10XX ALBERNI ST|            West End|491067.65|5459114.22|
# Offence Against a...|2003|    8| 30|null|  null|OFFSET TO PROTECT...|                null|      0.0|       0.0|
# +--------------------+----+-----+---+----+------+--------------------+--------------------+---------+----------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# Due to privacy concerns, the Vancouver Police Department have nullified the time and place of any violent records, so I won't include those for these neighbourhood-specific records.

# %%
# trim away NULL values
full_crime_df = crime_dataset
crime_df = crime_dataset.orderBy("YEAR").filter(crime_dataset["NEIGHBOURHOOD"]!="null")
crime_df.show(20)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+----+-----+---+----+------+--------------------+--------------------+---------+----------+
#                 TYPE|YEAR|MONTH|DAY|HOUR|MINUTE|       HUNDRED_BLOCK|       NEIGHBOURHOOD|        X|         Y|
# +--------------------+----+-----+---+----+------+--------------------+--------------------+---------+----------+
#   Theft from Vehicle|2003|    3|  3|  21|     0|    21XX WATERLOO ST|           Kitsilano|486927.58|5457222.16|
# Break and Enter R...|2003|   10| 17|  15|    30|      18XX COTTON DR|  Grandview-Woodland|494787.03|5457299.84|
#     Theft of Vehicle|2003|    6|  6|  15|     0|  32XX COMMERCIAL DR|Kensington-Cedar ...|494950.33|5455888.51|
# Break and Enter R...|2003|    7|  7|  11|     0|        66XX MAIN ST|              Sunset|492601.32|5452351.02|
# Break and Enter R...|2003|   11| 17|  19|    20|      33XX E 2ND AVE|    Hastings-Sunrise|497708.07|5457295.56|
# Break and Enter R...|2003|    2| 20|  11|    30|      33XX E 3RD AVE|    Hastings-Sunrise|497571.63|5457204.76|
#   Theft from Vehicle|2003|    1| 17|  16|    30|      6XX BURRARD ST|Central Business ...|491279.21|5459177.42|
#   Theft from Vehicle|2003|    1| 17|  21|    30|       21XX YORK AVE|           Kitsilano|488818.32| 5457672.4|
# Break and Enter R...|2003|    1| 18|   9|     0|      33XX E 2ND AVE|    Hastings-Sunrise|497666.36|5457305.02|
#   Theft from Vehicle|2003|   11|  3|  17|    55|BURRARD ST / COMO...|            West End|490757.46|5458643.86|
#   Theft from Vehicle|2003|    3| 11|  21|     0|   21XX WAVERLEY AVE| Victoria-Fraserview|495350.96|5452706.74|
# Break and Enter R...|2003|    6|  4|  15|    30|      18XX COTTON DR|  Grandview-Woodland|494796.22|5457303.43|
#   Theft from Vehicle|2003|    7| 11|  19|     0|  21XX WATERSIDE AVE| Victoria-Fraserview|495310.45|5450562.68|
# Break and Enter C...|2003|    9| 26|   2|    30|     10XX ALBERNI ST|            West End|491067.65|5459114.22|
#   Theft from Vehicle|2003|    6| 24|  20|     0|  21XX WATERSIDE AVE| Victoria-Fraserview|495310.45|5450562.68|
#   Theft from Vehicle|2003|    5| 14|   0|     0|   11XX CONNAUGHT DR|         Shaughnessy|490368.39|5454609.25|
# Break and Enter R...|2003|    5| 19|  22|    30|       18XX COMOX ST|            West End|489813.77|5459590.38|
#   Theft from Vehicle|2003|    1| 17|  18|    30|       21XX YORK AVE|           Kitsilano|488818.32| 5457672.4|
#   Theft from Vehicle|2003|    5| 17|  17|     0|      6XX BURRARD ST|Central Business ...|491279.21|5459177.42|
#   Theft from Vehicle|2003|    1| 10|   1|     0|       21XX YORK AVE|           Kitsilano|488818.32| 5457672.4|
# +--------------------+----+-----+---+----+------+--------------------+--------------------+---------+----------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ####Widget Control
# This modified dataframe can now be used for the neighbourhood widget, so that the user can dynamically control and explore different neighbourhoods and their crime statistics.

# %%
# widget control
neighbourhoods_list = crime_df.select("NEIGHBOURHOOD").distinct().rdd.flatMap(lambda x: x).collect()
dbutils.widgets.dropdown("neighbourhood", "Kitsilano", neighbourhoods_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ####Number of Crimes in Area
# The crimes are now specific to the neighbourhood variable that's currrently selected, and a count can be queried.

# %%
crimes = crime_df.filter(crime_df["NEIGHBOURHOOD"]==dbutils.widgets.get("neighbourhood"))

# count the number of crimes in the chosen neighbourhood
num_crimes = crimes.count()
print("There have been " + str(num_crimes) + " crimes in " + str(dbutils.widgets.get("neighbourhood")) + " since the year 2003.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">There have been 6185 crimes in Shaughnessy since the year 2003.
# </div>

# %% [markdown]
# ####Linear graph plotting the amount of crimes per year in this area from 2003 - 2018

# %%
# number of crimes each year since 2003 in the selected neighbourhood
crimes_per_year = crimes.groupBy("YEAR").count().orderBy("count").filter(crime_dataset["YEAR"]!="2019")
display(crimes_per_year)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YEAR</th><th>count</th></tr></thead><tbody><tr><td>2009</td><td>239</td></tr><tr><td>2010</td><td>257</td></tr><tr><td>2008</td><td>271</td></tr><tr><td>2013</td><td>275</td></tr><tr><td>2007</td><td>334</td></tr><tr><td>2006</td><td>336</td></tr><tr><td>2012</td><td>349</td></tr><tr><td>2011</td><td>351</td></tr><tr><td>2015</td><td>371</td></tr><tr><td>2014</td><td>376</td></tr><tr><td>2018</td><td>412</td></tr><tr><td>2016</td><td>417</td></tr><tr><td>2017</td><td>444</td></tr><tr><td>2003</td><td>519</td></tr><tr><td>2004</td><td>546</td></tr><tr><td>2005</td><td>556</td></tr></tbody></table></div>

# %% [markdown]
# ####Sum of Crimes in this Area Since 2003

# %%
from pyspark.sql.functions import desc
top_crimes = crimes.groupBy('TYPE').count().orderBy("count").sort(desc("count"))
display(top_crimes)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TYPE</th><th>count</th></tr></thead><tbody><tr><td>Theft from Vehicle</td><td>2086</td></tr><tr><td>Break and Enter Residential/Other</td><td>2000</td></tr><tr><td>Mischief</td><td>717</td></tr><tr><td>Vehicle Collision or Pedestrian Struck (with Injury)</td><td>650</td></tr><tr><td>Theft of Vehicle</td><td>389</td></tr><tr><td>Theft of Bicycle</td><td>159</td></tr><tr><td>Break and Enter Commercial</td><td>150</td></tr><tr><td>Other Theft</td><td>27</td></tr><tr><td>Vehicle Collision or Pedestrian Struck (with Fatality)</td><td>7</td></tr></tbody></table></div>

# %% [markdown]
# ####All of Vancouver
# Now we can see what the sum of all of the crimes - including violent crimes - looks like.
#
# A new DATE column can be added by just concatenating the year, month and day columns, and then casting to TimeStamp objects.

# %%
from pyspark.sql.functions import concat, col, lit
from pyspark.sql import functions as sf
import pyspark.sql

full_crime_df = full_crime_df.withColumn('DATE',
    sf.from_unixtime(sf.unix_timestamp(sf.concat(sf.col('YEAR'), sf.lit('-'), sf.col('MONTH'), sf.lit('-'), sf.col("DAY")), 'yyyy-MM-dd')).cast("timestamp"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data = full_crime_df.filter(full_crime_df["YEAR"] != "2019")
display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TYPE</th><th>YEAR</th><th>MONTH</th><th>DAY</th><th>HOUR</th><th>MINUTE</th><th>HUNDRED_BLOCK</th><th>NEIGHBOURHOOD</th><th>X</th><th>Y</th><th>DATE</th></tr></thead><tbody><tr><td>Theft from Vehicle</td><td>2003</td><td>5</td><td>14</td><td>0</td><td>0</td><td>11XX CONNAUGHT DR</td><td>Shaughnessy</td><td>490368.39</td><td>5454609.25</td><td>2003-05-14T00:00:00.000+0000</td></tr><tr><td>Break and Enter Residential/Other</td><td>2003</td><td>5</td><td>19</td><td>22</td><td>30</td><td>18XX COMOX ST</td><td>West End</td><td>489813.77</td><td>5459590.38</td><td>2003-05-19T00:00:00.000+0000</td></tr><tr><td>Theft from Vehicle</td><td>2003</td><td>1</td><td>17</td><td>21</td><td>30</td><td>21XX YORK AVE</td><td>Kitsilano</td><td>488818.32</td><td>5457672.4</td><td>2003-01-17T00:00:00.000+0000</td></tr><tr><td>Theft from Vehicle</td><td>2003</td><td>1</td><td>17</td><td>18</td><td>30</td><td>21XX YORK AVE</td><td>Kitsilano</td><td>488818.32</td><td>5457672.4</td><td>2003-01-17T00:00:00.000+0000</td></tr><tr><td>Theft from Vehicle</td><td>2003</td><td>5</td><td>17</td><td>17</td><td>0</td><td>6XX BURRARD ST</td><td>Central Business District</td><td>491279.21</td><td>5459177.42</td><td>2003-05-17T00:00:00.000+0000</td></tr><tr><td>Break and Enter Residential/Other</td><td>2003</td><td>1</td><td>18</td><td>9</td><td>0</td><td>33XX E 2ND AVE</td><td>Hastings-Sunrise</td><td>497666.36</td><td>5457305.02</td><td>2003-01-18T00:00:00.000+0000</td></tr><tr><td>Offence Against a Person</td><td>2003</td><td>11</td><td>1</td><td>null</td><td>null</td><td>OFFSET TO PROTECT PRIVACY</td><td>null</td><td>0.0</td><td>0.0</td><td>2003-11-01T00:00:00.000+0000</td></tr><tr><td>Break and Enter Residential/Other</td><td>2003</td><td>7</td><td>7</td><td>11</td><td>0</td><td>66XX MAIN ST</td><td>Sunset</td><td>492601.32</td><td>5452351.02</td><td>2003-07-07T00:00:00.000+0000</td></tr><tr><td>Theft from Vehicle</td><td>2003</td><td>1</td><td>10</td><td>1</td><td>0</td><td>21XX YORK AVE</td><td>Kitsilano</td><td>488818.32</td><td>5457672.4</td><td>2003-01-10T00:00:00.000+0000</td></tr><tr><td>Theft from Vehicle</td><td>2003</td><td>11</td><td>3</td><td>17</td><td>55</td><td>BURRARD ST / COMOX ST</td><td>West End</td><td>490757.46</td><td>5458643.86</td><td>2003-11-03T00:00:00.000+0000</td></tr><tr><td>Offence Against a Person</td><td>2003</td><td>4</td><td>27</td><td>null</td><td>null</td><td>OFFSET TO PROTECT PRIVACY</td><td>null</td><td>0.0</td><td>0.0</td><td>2003-04-27T00:00:00.000+0000</td></tr><tr><td>Theft from Vehicle</td><td>2003</td><td>3</td><td>11</td><td>21</td><td>0</td><td>21XX WAVERLEY AVE</td><td>Victoria-Fraserview</td><td>495350.96</td><td>5452706.74</td><td>2003-03-11T00:00:00.000+0000</td></tr><tr><td>Break and Enter Residential/Other</td><td>2003</td><td>11</td><td>17</td><td>19</td><td>20</td><td>33XX E 2ND AVE</td><td>Hastings-Sunrise</td><td>497708.07</td><td>5457295.56</td><td>2003-11-17T00:00:00.000+0000</td></tr><tr><td>Offence Against a Person</td><td>2003</td><td>11</td><td>4</td><td>null</td><td>null</td><td>OFFSET TO PROTECT PRIVACY</td><td>null</td><td>0.0</td><td>0.0</td><td>2003-11-04T00:00:00.000+0000</td></tr><tr><td>Break and Enter Residential/Other</td><td>2003</td><td>10</td><td>17</td><td>15</td><td>30</td><td>18XX COTTON DR</td><td>Grandview-Woodland</td><td>494787.03</td><td>5457299.84</td><td>2003-10-17T00:00:00.000+0000</td></tr><tr><td>Break and Enter Residential/Other</td><td>2003</td><td>6</td><td>4</td><td>15</td><td>30</td><td>18XX COTTON DR</td><td>Grandview-Woodland</td><td>494796.22</td><td>5457303.43</td><td>2003-06-04T00:00:00.000+0000</td></tr><tr><td>Theft from Vehicle</td><td>2003</td><td>7</td><td>11</td><td>19</td><td>0</td><td>21XX WATERSIDE AVE</td><td>Victoria-Fraserview</td><td>495310.45</td><td>5450562.68</td><td>2003-07-11T00:00:00.000+0000</td></tr><tr><td>Break and Enter Res ...

# %% [markdown]
# ####Sum of crimes in all of Vancouver since 2003

# %%
top_crimes = data.groupBy('TYPE').count().orderBy("count").sort(desc("count"))
display(top_crimes)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TYPE</th><th>count</th></tr></thead><tbody><tr><td>Theft from Vehicle</td><td>194705</td></tr><tr><td>Mischief</td><td>78964</td></tr><tr><td>Break and Enter Residential/Other</td><td>64425</td></tr><tr><td>Other Theft</td><td>59749</td></tr><tr><td>Offence Against a Person</td><td>59015</td></tr><tr><td>Theft of Vehicle</td><td>40320</td></tr><tr><td>Break and Enter Commercial</td><td>36952</td></tr><tr><td>Theft of Bicycle</td><td>29092</td></tr><tr><td>Vehicle Collision or Pedestrian Struck (with Injury)</td><td>24232</td></tr><tr><td>Vehicle Collision or Pedestrian Struck (with Fatality)</td><td>276</td></tr><tr><td>Homicide</td><td>241</td></tr></tbody></table></div>

# %% [markdown]
# Judging from the counts of each kind of crime, it seems that theft is the most prevalent crime.

# %% [markdown]
# ####Crime Categories
#
# Now that the crime list includes violent offences as well, we should split it up into 5 new categories:
# 1. Theft
# 2. Mischief
# 3. Vehicle Accidents
# 4. Violent Offences
# 5. Break and Enter (BNE)

# %%
# cut everything except YEAR TYPE COUNT
crimes = full_crime_df.select("YEAR", "TYPE").sort("YEAR")

# category lists
theft = ["Theft from Vehicle", "Other Theft", "Theft of Vehicle", "Theft of Bicycle"]
vehicle = ["Vehicle Collision or Pedestrian Struck (with Injury)", "Vehicle Collision or Pedestrian Struck (with Fatality)"]
violence = ["Offence Against a Person", "Homicide"]
bne = ["Break and Enter Residential/Other", "Break and Enter Commercial"]

# put all crimes into categories (mischief is just by itself)
crimes = crimes.na.replace(theft, "Theft")
crimes = crimes.na.replace(vehicle, "Vehicle Accidents")
crimes = crimes.na.replace(violence, "Violent Offences")
crimes = crimes.na.replace(bne, "BNE")

# reshape the dataframe so that it has the counts of each category split into each year
data_counts = crimes.groupBy(["YEAR", "TYPE"]).count().alias("COUNT")
data_joined = crimes.join(data_counts, ["YEAR", "TYPE"]).dropDuplicates()
reshaped_df = data_joined.groupby('YEAR').pivot('TYPE').max('count')
crimes = reshaped_df.filter(crimes["YEAR"] != "2019").orderBy("YEAR")
display(crimes)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YEAR</th><th>BNE</th><th>Mischief</th><th>Theft</th><th>Vehicle Accidents</th><th>Violent Offences</th></tr></thead><tbody><tr><td>2003</td><td>10080</td><td>6391</td><td>28105</td><td>1827</td><td>3528</td></tr><tr><td>2004</td><td>9821</td><td>5601</td><td>28141</td><td>1890</td><td>3811</td></tr><tr><td>2005</td><td>8181</td><td>5062</td><td>25612</td><td>2016</td><td>3805</td></tr><tr><td>2006</td><td>8518</td><td>5184</td><td>22849</td><td>1404</td><td>4363</td></tr><tr><td>2007</td><td>7432</td><td>4810</td><td>19758</td><td>1261</td><td>4442</td></tr><tr><td>2008</td><td>6656</td><td>5276</td><td>18036</td><td>1202</td><td>4245</td></tr><tr><td>2009</td><td>5355</td><td>4429</td><td>17192</td><td>1292</td><td>3906</td></tr><tr><td>2010</td><td>4927</td><td>4506</td><td>15179</td><td>1337</td><td>3755</td></tr><tr><td>2011</td><td>4980</td><td>4828</td><td>13608</td><td>1273</td><td>3905</td></tr><tr><td>2012</td><td>4998</td><td>4243</td><td>14695</td><td>1492</td><td>3803</td></tr><tr><td>2013</td><td>4799</td><td>4191</td><td>14897</td><td>1501</td><td>3683</td></tr><tr><td>2014</td><td>5288</td><td>4518</td><td>18102</td><td>1589</td><td>3166</td></tr><tr><td>2015</td><td>5577</td><td>4191</td><td>19660</td><td>1684</td><td>3238</td></tr><tr><td>2016</td><td>5681</td><td>4599</td><td>22633</td><td>1721</td><td>3206</td></tr><tr><td>2017</td><td>4662</td><td>5393</td><td>22165</td><td>1533</td><td>3244</td></tr><tr><td>2018</td><td>4422</td><td>5742</td><td>23234</td><td>1486</td><td>3156</td></tr></tbody></table></div>

# %% [markdown]
# #####Judging by the graph above, a few speculations can be made:
# - Theft was declining, but since 2011 has been increasing again
# - Vehicle Accidents have remained steady since 2003
# - BNEs are slowly declining (possibly due to better security in cars and buildings)

# %% [markdown]
# ####Incorporating Property Values
#
# Now that we have the crimes nice and sorted into categories by year, we can find the average property value price per year and append it to the crime dataframe, setting it up for the linear regressions.

# %%
# store the 2006 - 2018 property tax dataframes in a dictionary as {year: df}
property_dict = {}

# read the dataset in from the DBFS, and select only the columns from the older datasets 
# as the newer ones have a few extra columns that we don't need
for year in range(2006, 2018 + 1):
  property_dict[year] = spark.read.csv("/FileStore/tables/property_tax_report{}.csv".format(year), inferSchema=True, header=True).select("TAX_ASSESSMENT_YEAR", "CURRENT_LAND_VALUE", "CURRENT_IMPROVEMENT_VALUE", "PID", "LEGAL_TYPE", "FOLIO", "LAND_COORDINATE", "LOT", "BLOCK", "PLAN", "DISTRICT_LOT", "FROM_CIVIC_NUMBER", "TO_CIVIC_NUMBER", "STREET_NAME", "PROPERTY_POSTAL_CODE", "NARRATIVE_LEGAL_LINE1", "NARRATIVE_LEGAL_LINE2", "NARRATIVE_LEGAL_LINE3", "NARRATIVE_LEGAL_LINE4", "NARRATIVE_LEGAL_LINE5", "YEAR_BUILT", "BIG_IMPROVEMENT_YEAR", "TAX_LEVY", "NEIGHBOURHOOD_CODE")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#combining all of the years
property_df = property_dict[2006].union(property_dict[2007])
for year in range(2006, 2018 + 1):
  if year != 2006:
    property_df = property_df.union(property_dict[year])
    
print(property_dict.keys())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dict_keys([2016, 2017, 2018, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015])
# </div>

# %% [markdown]
# The current land value and current property value will be added together to get an overall value for each property.

# %%
property_df = property_df.withColumn("OVERALL_VALUE", sf.col("CURRENT_LAND_VALUE") + sf.col("CURRENT_IMPROVEMENT_VALUE"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(property_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TAX_ASSESSMENT_YEAR</th><th>CURRENT_LAND_VALUE</th><th>CURRENT_IMPROVEMENT_VALUE</th><th>PID</th><th>LEGAL_TYPE</th><th>FOLIO</th><th>LAND_COORDINATE</th><th>LOT</th><th>BLOCK</th><th>PLAN</th><th>DISTRICT_LOT</th><th>FROM_CIVIC_NUMBER</th><th>TO_CIVIC_NUMBER</th><th>STREET_NAME</th><th>PROPERTY_POSTAL_CODE</th><th>NARRATIVE_LEGAL_LINE1</th><th>NARRATIVE_LEGAL_LINE2</th><th>NARRATIVE_LEGAL_LINE3</th><th>NARRATIVE_LEGAL_LINE4</th><th>NARRATIVE_LEGAL_LINE5</th><th>YEAR_BUILT</th><th>BIG_IMPROVEMENT_YEAR</th><th>TAX_LEVY</th><th>NEIGHBOURHOOD_CODE</th><th>OVERALL_VALUE</th></tr></thead><tbody><tr><td>2006</td><td>84600</td><td>481000</td><td>018-392-164</td><td>LAND</td><td>120590054001</td><td>12059005</td><td>1</td><td>1</td><td>LMP11726</td><td>185</td><td>null</td><td>401</td><td>BURRARD ST</td><td>V6C 3R2</td><td>LOT 1  BLOCK 1  PLAN LMP11726  DIST</td><td>RICT LOT 185  NEW WESTMINSTER</td><td>null</td><td>null</td><td>null</td><td>2002</td><td>2002</td><td>null</td><td>26</td><td>565600.0</td></tr><tr><td>2006</td><td>73353</td><td>135830</td><td>026-600-439</td><td>STRATA</td><td>646122720002</td><td>64612272</td><td>2</td><td>null</td><td>BCS1732</td><td>526</td><td>null</td><td>1654</td><td>7TH AVE W</td><td>V6J 1S5</td><td>LOT 2  PLAN BCS1732  DISTRICT LOT 5</td><td>26  NEW WESTMINSTER GROUP 1.</td><td>null</td><td>null</td><td>null</td><td>2006</td><td>2006</td><td>1179.49</td><td>7</td><td>209183.0</td></tr><tr><td>2006</td><td>67600</td><td>125177</td><td>026-600-447</td><td>STRATA</td><td>646122720003</td><td>64612272</td><td>3</td><td>null</td><td>BCS1732</td><td>526</td><td>null</td><td>1648</td><td>7TH AVE W</td><td>V6J 1S5</td><td>LOT 3  PLAN BCS1732  DISTRICT LOT 5</td><td>26  NEW WESTMINSTER GROUP 1.</td><td>null</td><td>null</td><td>null</td><td>2006</td><td>2006</td><td>1086.97</td><td>7</td><td>192777.0</td></tr><tr><td>2006</td><td>74072</td><td>137162</td><td>026-600-455</td><td>STRATA</td><td>646122720004</td><td>64612272</td><td>4</td><td>null</td><td>BCS1732</td><td>526</td><td>null</td><td>1644</td><td>7TH AVE W</td><td>V6J 1S5</td><td>LOT 4  PLAN BCS1732  DISTRICT LOT 5</td><td>26  NEW WESTMINSTER GROUP 1.</td><td>null</td><td>null</td><td>null</td><td>2006</td><td>2006</td><td>1191.04</td><td>7</td><td>211234.0</td></tr><tr><td>2006</td><td>84140</td><td>155805</td><td>026-600-463</td><td>STRATA</td><td>646122720005</td><td>64612272</td><td>5</td><td>null</td><td>BCS1732</td><td>526</td><td>null</td><td>1640</td><td>7TH AVE W</td><td>V6J 1S5</td><td>LOT 5  PLAN BCS1732  DISTRICT LOT 5</td><td>26  NEW WESTMINSTER GROUP 1.</td><td>null</td><td>null</td><td>null</td><td>2006</td><td>2006</td><td>1352.93</td><td>7</td><td>239945.0</td></tr><tr><td>2006</td><td>84140</td><td>155805</td><td>026-600-471</td><td>STRATA</td><td>646122720006</td><td>64612272</td><td>6</td><td>null</td><td>BCS1732</td><td>526</td><td>null</td><td>1636</td><td>7TH AVE W</td><td>V6J 1S5</td><td>LOT 6  PLAN BCS1732  DISTRICT LOT 5</td><td>26  NEW WESTMINSTER GROUP 1.</td><td>null</td><td>null</td><td>null</td><td>2006</td><td>2006</td><td>1352.93</td><td>7</td><td>239945.0</td></tr><tr><td>2006</td><td>84140</td><td>155805</td><td>026-600-480</td><td>STRATA</td><td>646122720007</td><td>64612272</td><td>7</td><td>null</td><td>BCS1732</td><td>526</td><td>null</td><td>1632</td><td>7TH AVE W</td><td>V6J 1S5</td><td>LOT 7  PLAN BCS1732  DISTRICT LOT 5</td><td>26  NEW WESTMINSTER GROUP 1.</td><td>null</td><td>null</td><td>null</td><td>2006</td><td>2006</td><td>1352.93</td><td>7</td><td>239945.0</td></tr><tr><td>2006</td><td>84140</td><td>155805</td><td>026-600-498</td><td>STRATA</td><td>646122720008</td><td>64612272</td><td>8</td><td>null</td><td>BCS1732</td><td>526</td><td>null</td><td>1628</td><td>7TH AVE W</td><td>V6J 1S5</td><td>LOT 8  PLAN BCS1732  DISTRICT LOT 5</td><td>26  NEW WESTMINSTER GROUP 1.</td><td>null</ ...

# %% [markdown]
# Now all of the other columns besides year and overall value can be removed, and the average for each year can be found

# %%
# trim all columns except year and overall
prop_df = property_df.select(["TAX_ASSESSMENT_YEAR", "OVERALL_VALUE"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import mean

prop_df = (prop_df
    .groupBy("TAX_ASSESSMENT_YEAR")
    .agg(mean("OVERALL_VALUE").alias("MEAN"))
    .filter(prop_df["TAX_ASSESSMENT_YEAR"] >= 2006)
    .filter(prop_df["TAX_ASSESSMENT_YEAR"] <= 2019)
    .orderBy("TAX_ASSESSMENT_YEAR", ascending=True))
display(prop_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TAX_ASSESSMENT_YEAR</th><th>MEAN</th></tr></thead><tbody><tr><td>2006</td><td>723236.621305649</td></tr><tr><td>2007</td><td>883140.8572400311</td></tr><tr><td>2008</td><td>1016126.7539754785</td></tr><tr><td>2009</td><td>1007951.8997503361</td></tr><tr><td>2010</td><td>1009410.0458366973</td></tr><tr><td>2011</td><td>1126718.7324790321</td></tr><tr><td>2012</td><td>1266256.9328822477</td></tr><tr><td>2013</td><td>1283530.1136879553</td></tr><tr><td>2014</td><td>1300409.1826707004</td></tr><tr><td>2015</td><td>1408748.9028200025</td></tr><tr><td>2016</td><td>1622112.4676377024</td></tr><tr><td>2017</td><td>2086499.3656747644</td></tr><tr><td>2018</td><td>2228273.8326920653</td></tr></tbody></table></div>

# %% [markdown]
# Finally, the two dataframes can be combined.

# %%
crimes = crimes.filter(crimes["YEAR"] >= 2006).filter(crimes["YEAR"] <= 2018)
prop_df = prop_df.selectExpr("TAX_ASSESSMENT_YEAR as YEAR", "MEAN as MEAN_VAL")
data = crimes.join(prop_df, on=["YEAR"]) #.sort("row_index").drop("row_index")

display(data.orderBy("YEAR", ascending=True))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YEAR</th><th>BNE</th><th>Mischief</th><th>Theft</th><th>Vehicle Accidents</th><th>Violent Offences</th><th>MEAN_VAL</th></tr></thead><tbody><tr><td>2006</td><td>8518</td><td>5184</td><td>22849</td><td>1404</td><td>4363</td><td>723236.621305649</td></tr><tr><td>2007</td><td>7432</td><td>4810</td><td>19758</td><td>1261</td><td>4442</td><td>883140.8572400311</td></tr><tr><td>2008</td><td>6656</td><td>5276</td><td>18036</td><td>1202</td><td>4245</td><td>1016126.7539754785</td></tr><tr><td>2009</td><td>5355</td><td>4429</td><td>17192</td><td>1292</td><td>3906</td><td>1007951.8997503361</td></tr><tr><td>2010</td><td>4927</td><td>4506</td><td>15179</td><td>1337</td><td>3755</td><td>1009410.0458366973</td></tr><tr><td>2011</td><td>4980</td><td>4828</td><td>13608</td><td>1273</td><td>3905</td><td>1126718.7324790321</td></tr><tr><td>2012</td><td>4998</td><td>4243</td><td>14695</td><td>1492</td><td>3803</td><td>1266256.9328822477</td></tr><tr><td>2013</td><td>4799</td><td>4191</td><td>14897</td><td>1501</td><td>3683</td><td>1283530.1136879553</td></tr><tr><td>2014</td><td>5288</td><td>4518</td><td>18102</td><td>1589</td><td>3166</td><td>1300409.1826707004</td></tr><tr><td>2015</td><td>5577</td><td>4191</td><td>19660</td><td>1684</td><td>3238</td><td>1408748.9028200025</td></tr><tr><td>2016</td><td>5681</td><td>4599</td><td>22633</td><td>1721</td><td>3206</td><td>1622112.4676377024</td></tr><tr><td>2017</td><td>4662</td><td>5393</td><td>22165</td><td>1533</td><td>3244</td><td>2086499.3656747644</td></tr><tr><td>2018</td><td>4422</td><td>5742</td><td>23234</td><td>1486</td><td>3156</td><td>2228273.8326920653</td></tr></tbody></table></div>

# %% [markdown]
# ###Linear Regressions
#
# Now we can use PySparks MLlib to perform some linear regressions, trying to see which variables affect what.

# %%
# predict the label from the features
feature_columns = data.columns[:-1] # omitting the final column

from pyspark.ml.feature import VectorAssembler

assembler = VectorAssembler(inputCols=feature_columns,outputCol="features")

data_2 = assembler.transform(data)

data_2.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+----+--------+-----+-----------------+----------------+------------------+--------------------+
# YEAR| BNE|Mischief|Theft|Vehicle Accidents|Violent Offences|          MEAN_VAL|            features|
# +----+----+--------+-----+-----------------+----------------+------------------+--------------------+
# 2007|7432|    4810|19758|             1261|            4442| 883140.8572400311|[2007.0,7432.0,48...|
# 2018|4422|    5742|23234|             1486|            3156|2228273.8326920653|[2018.0,4422.0,57...|
# 2015|5577|    4191|19660|             1684|            3238|1408748.9028200025|[2015.0,5577.0,41...|
# 2006|8518|    5184|22849|             1404|            4363|  723236.621305649|[2006.0,8518.0,51...|
# 2013|4799|    4191|14897|             1501|            3683|1283530.1136879553|[2013.0,4799.0,41...|
# 2014|5288|    4518|18102|             1589|            3166|1300409.1826707004|[2014.0,5288.0,45...|
# 2012|4998|    4243|14695|             1492|            3803|1266256.9328822477|[2012.0,4998.0,42...|
# 2009|5355|    4429|17192|             1292|            3906|1007951.8997503361|[2009.0,5355.0,44...|
# 2016|5681|    4599|22633|             1721|            3206|1622112.4676377024|[2016.0,5681.0,45...|
# 2010|4927|    4506|15179|             1337|            3755|1009410.0458366973|[2010.0,4927.0,45...|
# 2011|4980|    4828|13608|             1273|            3905|1126718.7324790321|[2011.0,4980.0,48...|
# 2008|6656|    5276|18036|             1202|            4245|1016126.7539754785|[2008.0,6656.0,52...|
# 2017|4662|    5393|22165|             1533|            3244|2086499.3656747644|[2017.0,4662.0,53...|
# +----+----+--------+-----+-----------------+----------------+------------------+--------------------+
#
# </div>

# %%
#split the data into a train set and a test set
train, test = data_2.randomSplit([0.7, 0.3])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# training the learning algorithm
from pyspark.ml.regression import LinearRegression
algo = LinearRegression(featuresCol="features", labelCol="MEAN_VAL")
model = algo.fit(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# evaluation of the model's performance
evaluation_summary = model.evaluate(test)
print("Mean absolute error: ", evaluation_summary.meanAbsoluteError)
print("\nRoot mean squared error: ", evaluation_summary.rootMeanSquaredError)
print("\nR2: ", evaluation_summary.r2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Mean absolute error:  79684.60113461953
#
# Root mean squared error:  83545.6529129493
#
# R2:  0.6385679950311804
# </div>

# %%
# predicting the test values
predictions = model.transform(test)
predictions.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+----+--------+-----+-----------------+----------------+------------------+--------------------+------------------+
# YEAR| BNE|Mischief|Theft|Vehicle Accidents|Violent Offences|          MEAN_VAL|            features|        prediction|
# +----+----+--------+-----+-----------------+----------------+------------------+--------------------+------------------+
# 2007|7432|    4810|19758|             1261|            4442| 883140.8572400311|[2007.0,7432.0,48...| 763385.1378733814|
# 2012|4998|    4243|14695|             1492|            3803|1266256.9328822477|[2012.0,4998.0,42...| 1210195.096312642|
# 2010|4927|    4506|15179|             1337|            3755|1009410.0458366973|[2010.0,4927.0,45...|1070335.8092644513|
# 2008|6656|    5276|18036|             1202|            4245|1016126.7539754785|[2008.0,6656.0,52...| 934131.6688010097|
# +----+----+--------+-----+-----------------+----------------+------------------+--------------------+------------------+
#
# </div>

# %% [markdown]
# ###Future Trends
#
# Now that the model is trained according to the crime rates, lets see how manipulating these variables will affect the future property values.  First, let's see what happens when each crime category drops by 70 each year (+350 total over 5 years)

# %%
# values for 2018
year = 2018
bne = 4422
mischief = 5742
theft = 23234
vehicle = 1486
violence = 3156

# multiplier
m = -70

# assume crime rates will drop down by 50 per category per year
rdd = sc.parallelize([(year+1, bne-m, mischief-m, theft-m, vehicle-m, violence-m),
                      (year+2, bne-m*2, mischief-m*2, theft-m*2, vehicle-m*2, violence-m*2),
                      (year+3, bne-m*3, mischief-m*3, theft-m*3, vehicle-m*3, violence-m*3),
                      (year+4, bne-m*4, mischief-m*4, theft-m*4, vehicle-m*4, violence-m*4),
                      (year+5, bne-m*5, mischief-m*5, theft-m*5, vehicle-m*5, violence-m*5)])
future_df = rdd.toDF(["YEAR", "BNE", "Mischief", "Theft", "Vehicle Accidents", "Violent Offences"])

# apply the model to the new df
data_3 = assembler.transform(future_df)
five_years = model.transform(data_3)
display(five_years)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YEAR</th><th>BNE</th><th>Mischief</th><th>Theft</th><th>Vehicle Accidents</th><th>Violent Offences</th><th>features</th><th>prediction</th></tr></thead><tbody><tr><td>2019</td><td>4492</td><td>5812</td><td>23304</td><td>1556</td><td>3226</td><td>List(1, 6, List(), List(2019.0, 4492.0, 5812.0, 23304.0, 1556.0, 3226.0))</td><td>2379805.7814376354</td></tr><tr><td>2020</td><td>4562</td><td>5882</td><td>23374</td><td>1626</td><td>3296</td><td>List(1, 6, List(), List(2020.0, 4562.0, 5882.0, 23374.0, 1626.0, 3296.0))</td><td>2516544.690096006</td></tr><tr><td>2021</td><td>4632</td><td>5952</td><td>23444</td><td>1696</td><td>3366</td><td>List(1, 6, List(), List(2021.0, 4632.0, 5952.0, 23444.0, 1696.0, 3366.0))</td><td>2653283.598754376</td></tr><tr><td>2022</td><td>4702</td><td>6022</td><td>23514</td><td>1766</td><td>3436</td><td>List(1, 6, List(), List(2022.0, 4702.0, 6022.0, 23514.0, 1766.0, 3436.0))</td><td>2790022.5074127316</td></tr><tr><td>2023</td><td>4772</td><td>6092</td><td>23584</td><td>1836</td><td>3506</td><td>List(1, 6, List(), List(2023.0, 4772.0, 6092.0, 23584.0, 1836.0, 3506.0))</td><td>2926761.416071117</td></tr></tbody></table></div>

# %% [markdown]
# ####Housing Market Increases
#
# When each category is increased by a margin of 70 each year, the housing market rises.
#
# Let's see what happens when the OPPOSITE is applied, when each year's categories go down by 70 each year.

# %%
# multiplier
m = 70

# assume crime rates will drop down by 50 per category per year
rdd2 = sc.parallelize([(year+1, bne-m, mischief-m, theft-m, vehicle-m, violence-m),
                      (year+2, bne-m*2, mischief-m*2, theft-m*2, vehicle-m*2, violence-m*2),
                      (year+3, bne-m*3, mischief-m*3, theft-m*3, vehicle-m*3, violence-m*3),
                      (year+4, bne-m*4, mischief-m*4, theft-m*4, vehicle-m*4, violence-m*4),
                      (year+5, bne-m*5, mischief-m*5, theft-m*5, vehicle-m*5, violence-m*5)])
future_df2 = rdd2.toDF(["YEAR", "BNE", "Mischief", "Theft", "Vehicle Accidents", "Violent Offences"])

# apply the model to the new df
data_4 = assembler.transform(future_df2)
five_years2 = model.transform(data_4)
display(five_years2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YEAR</th><th>BNE</th><th>Mischief</th><th>Theft</th><th>Vehicle Accidents</th><th>Violent Offences</th><th>features</th><th>prediction</th></tr></thead><tbody><tr><td>2019</td><td>4352</td><td>5672</td><td>23164</td><td>1416</td><td>3086</td><td>List(1, 6, List(), List(2019.0, 4352.0, 5672.0, 23164.0, 1416.0, 3086.0))</td><td>2234801.08665812</td></tr><tr><td>2020</td><td>4282</td><td>5602</td><td>23094</td><td>1346</td><td>3016</td><td>List(1, 6, List(), List(2020.0, 4282.0, 5602.0, 23094.0, 1346.0, 3016.0))</td><td>2226535.30053699</td></tr><tr><td>2021</td><td>4212</td><td>5532</td><td>23024</td><td>1276</td><td>2946</td><td>List(1, 6, List(), List(2021.0, 4212.0, 5532.0, 23024.0, 1276.0, 2946.0))</td><td>2218269.514415875</td></tr><tr><td>2022</td><td>4142</td><td>5462</td><td>22954</td><td>1206</td><td>2876</td><td>List(1, 6, List(), List(2022.0, 4142.0, 5462.0, 22954.0, 1206.0, 2876.0))</td><td>2210003.728294745</td></tr><tr><td>2023</td><td>4072</td><td>5392</td><td>22884</td><td>1136</td><td>2806</td><td>List(1, 6, List(), List(2023.0, 4072.0, 5392.0, 22884.0, 1136.0, 2806.0))</td><td>2201737.942173615</td></tr></tbody></table></div>

# %% [markdown]
# ####Housing market decreases
#
# Now, when the crime rates DECREASE, the property market also goes down with it.

# %% [markdown]
# ###Speculations and Conclusions
#
# It seems to be that the property market and the crime rates seems to be somewhat related.  As the crime rates rise, so does the market, and when they fall, the market falls as well.  This seems counter-intuitive, but actually makes sense if thought about.
#
# When the housing market is rising, more people can't afford housing, and in turn begin commiting more crimes.
# The opposite can also be said, as when the housing market is lowering and more affordable, less people have to turn to crime.

# %%
#todo add more test cases to the model to see how multiple situations would work (i.e. higher thefts and lower BNE)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
